# %%
import requests
import json


url = 'https://api.who-umc.org/vigibase/icsrstatistics/dimensions/drug?tradename='

drug_name = ['rosiglitazone']

headers = {
    'Authorization'  : "Basic VmlnaUJhc2VBY2Nlc3NDbGllbnQ6cHN3ZDRWaUE=",
    'umc-client-key' : '6d851d41-f558-4805-a9a6-08df0e0e414b'
}

for name in drug_name:
    print(name)
    r = requests.get(url + name, headers=headers)
    d = json.loads(r.text)
    drug_code = d[0]['Code']
    api_url = "https://api.who-umc.org/vigibase/icsrstatistics/distributions?agegroupFilter=&continentFilter=&reactionFilter=&sexFilter=&substanceFilter=" + drug_code
    r = requests.get(api_url, headers=headers)
    d = json.loads(r.text)
    #print(d['AdrObservations'])
# Out:
# rosiglitazone

# %%
import pandas
df=pandas.DataFrame(d['AdrObservations'])

# %%
df
# Out:
#                                                 Group  \
# 0                Blood and lymphatic system disorders
# 1                                   Cardiac disorders
# 2          Congenital, familial and genetic disorders
# 3                         Ear and labyrinth disorders
# 4                                 Endocrine disorders
# 5                                       Eye disorders
# 6                          Gastrointestinal disorders
# 7   General disorders and administration site cond...
# 8                             Hepatobiliary disorders
# 9                             Immune system disorders
# 10                        Infections and infestations
# 11     Injury, poisoning and procedural complications
# 12                                     Investigations
# 13                 Metabolism and nutrition disorders
# 14    Musculoskeletal and connective tissue disorders
# 15  Neoplasms benign, malignant and unspecified (i...
# ...
